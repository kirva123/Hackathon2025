# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
from shapely import wkt
from shapely.geometry import Point, box
import datetime as dt
import seaborn as sns

# %%
nodes = pd.read_csv("node_data.csv")
edges = pd.read_csv("data/edges_data.csv")
df_2020 = pd.read_csv("data/scats_detector_volume_jan-jun-2020.csv")
sites = pd.read_csv("data/its_scats_sites_aug-2020.csv")

# %%
columns_to_load = ["End_Time", "Site", "Detector", "Sum_Volume", "Avg_Volume"]
March2025 = pd.read_csv("data/SCATSMarch2025.csv", usecols=columns_to_load)

# %%
April2025 = pd.read_csv("data/SCATSApril2025.csv", usecols=columns_to_load)

# %%
May2025 = pd.read_csv("data/SCATSMay2025.csv", usecols=columns_to_load)

# %%
df  = pd.concat([March2025, April2025], ignore_index=True)

# %%
geo_edges=edges.copy()
# Convert the 'geometry' column from WKT to Shapely geometries
geo_edges['geometry'] = edges['geometry'].apply(wkt.loads)

# Wrap as a GeoDataFrame
geo_edges = gpd.GeoDataFrame(geo_edges, geometry='geometry')

# Set the CRS (optional, replace with your CRS if known)
geo_edges.set_crs(epsg=4326, inplace=True)

# Now this is a true GeoDataFrame
print(type(geo_edges))
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>

# %%
geo_nodes=nodes.copy()
# Convert the 'geometry' column from WKT to Shapely geometries
geo_nodes['geometry'] = nodes['geometry'].apply(wkt.loads)

# Wrap as a GeoDataFrame
geo_nodes = gpd.GeoDataFrame(geo_nodes, geometry='geometry')

# Set the CRS (optional, replace with your CRS if known)
geo_nodes.set_crs(epsg=4326, inplace=True)

# Now this is a true GeoDataFrame
print(type(geo_nodes))
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>

# %%
sites = sites[~((sites["Lat"] == 0) | (sites["Long"] == 0))]
geo_sites = gpd.GeoDataFrame(
    sites,
    geometry=gpd.points_from_xy(sites['Long'], sites['Lat']),
    crs="EPSG:4326"  # WGS84 coordinate system (lat/long)
)

# %%
fig, ax = plt.subplots(figsize=(10, 10))

# Plot edges first (usually as lines)
geo_edges.plot(ax=ax, color='blue', linewidth=1, label='Edges')

# Plot nodes on top (usually as points)
geo_sites.plot(ax=ax, color='red', markersize=5, label='Sites')

# Optional: add a legend and title
plt.legend()
plt.title("Nodes and Edges")

plt.show()

# %%
# Get bounding box of all points
minx, miny, maxx, maxy = geo_edges.total_bounds

# Define grid size (in the CRS units, e.g., degrees if EPSG:4326)
nx = 10  # number of columns
ny = 10  # number of rows
xgrid = np.linspace(minx, maxx, nx+1)
ygrid = np.linspace(miny, maxy, ny+1)

# Create grid polygons
polygons = []
for i in range(nx):
    for j in range(ny):
        polygons.append(box(xgrid[i], ygrid[j], xgrid[i+1], ygrid[j+1]))

grid = gpd.GeoDataFrame({'geometry': polygons}, crs=geo_edges.crs)

# %%
df_small = df[["End_Time","Site","Detector","Sum_Volume"]]  # only necessary columns
geo_small = geo_sites[['SiteID', 'geometry']]
df_small['Site'] = df_small['Site'].astype('category')
geo_small['SiteID'] = geo_small['SiteID'].astype('category')
# Out:
# C:\Users\user1\AppData\Local\Temp\ipykernel_7944\4000184562.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_small['Site'] = df_small['Site'].astype('category')
# c:\Users\user1\AppData\Local\Programs\Python\Python313\Lib\site-packages\geopandas\geodataframe.py:1968: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
gdf = pd.merge(df_small, geo_small, left_on ="Site", right_on = "SiteID", how = "inner")

gdf.head()
# Out:
#          End_Time  Site  Detector  Sum_Volume SiteID  \
# 0  20250313010000    58         6           0   58.0
# 1  20250313010000    58         7           5   58.0
# 2  20250313010000    58         8           0   58.0
# 3  20250313010000    58         9           0   58.0
# 4  20250313010000    58        10           0   58.0
#
#                     geometry
# 0  POINT (-6.26523 53.35605)
# 1  POINT (-6.26523 53.35605)
# 2  POINT (-6.26523 53.35605)
# 3  POINT (-6.26523 53.35605)
# 4  POINT (-6.26523 53.35605)

# %%
gdf=gdf.drop("SiteID", axis = 1)
gdf["End_Time"] = pd.to_datetime(gdf["End_Time"], format="%Y%m%d%H%M%S")
gdf.head()
# Out:
#              End_Time  Site  Detector  Sum_Volume                   geometry
# 0 2025-03-13 01:00:00    58         6           0  POINT (-6.26523 53.35605)
# 1 2025-03-13 01:00:00    58         7           5  POINT (-6.26523 53.35605)
# 2 2025-03-13 01:00:00    58         8           0  POINT (-6.26523 53.35605)
# 3 2025-03-13 01:00:00    58         9           0  POINT (-6.26523 53.35605)
# 4 2025-03-13 01:00:00    58        10           0  POINT (-6.26523 53.35605)

# %%
gdf = gpd.GeoDataFrame(
    gdf,
    geometry=gdf["geometry"],
    crs="EPSG:4326"  # WGS84 coordinate system (lat/long)
)

# %%
# Spatial join points to grid boxes
joined = gpd.sjoin(gdf, grid, how='left', predicate='within')
joined = joined.rename(columns={"index_right": "Grid_ID"})

# Sum Sum_volume per grid cell
grid_sum = joined.groupby('Grid_ID')['Sum_Volume'].sum()

# Assign sums to the grid GeoDataFrame
grid['Sum_volume'] = grid_sum
grid['Sum_volume'] = grid['Sum_volume'].fillna(0)  # fill empty cells

# %%
grid.index.name = "Grid_ID"
grid.head()

#grid.set_index("Grid_ID", inplace=True)
# Out:
#                                                   geometry  Sum_volume
# Grid_ID
# 0        POLYGON ((-6.36199 53.3018, -6.36199 53.31262,...         0.0
# 1        POLYGON ((-6.36199 53.31262, -6.36199 53.32344...         0.0
# 2        POLYGON ((-6.36199 53.32344, -6.36199 53.33426...         0.0
# 3        POLYGON ((-6.36199 53.33426, -6.36199 53.34507...   1857254.0
# 4        POLYGON ((-6.36199 53.34507, -6.36199 53.35589...   2035809.0

# %%
joined.head()
# Out:
#              End_Time  Site  Detector  Sum_Volume                   geometry  \
# 0 2025-03-13 01:00:00    58         6           0  POINT (-6.26523 53.35605)
# 1 2025-03-13 01:00:00    58         7           5  POINT (-6.26523 53.35605)
# 2 2025-03-13 01:00:00    58         8           0  POINT (-6.26523 53.35605)
# 3 2025-03-13 01:00:00    58         9           0  POINT (-6.26523 53.35605)
# 4 2025-03-13 01:00:00    58        10           0  POINT (-6.26523 53.35605)
#
#    Grid_ID
# 0     45.0
# 1     45.0
# 2     45.0
# 3     45.0
# 4     45.0

# %%
joined_eval = joined.groupby(["Grid_ID","End_Time"]).agg({
    "Sum_Volume": "sum"
}).reset_index()
joined_eval.head()
# Out:
#    Grid_ID            End_Time  Sum_Volume
# 0      3.0 2025-03-01 00:00:00         897
# 1      3.0 2025-03-01 01:00:00         551
# 2      3.0 2025-03-01 02:00:00         492
# 3      3.0 2025-03-01 03:00:00         272
# 4      3.0 2025-03-01 04:00:00         247

# %%
joined_eval = joined_eval.sort_values("Grid_ID")
joined_eval.head()
# Out:
#    Grid_ID            End_Time  Sum_Volume
# 0      3.0 2025-03-01 00:00:00         897
# 1      3.0 2025-03-01 01:00:00         551
# 2      3.0 2025-03-01 02:00:00         492
# 3      3.0 2025-03-01 03:00:00         272
# 4      3.0 2025-03-01 04:00:00         247

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
grid.plot(column='Sum_volume', ax=ax, cmap='OrRd', legend=True, edgecolor='k')
geo_edges.plot(ax=ax, color='blue', linewidth=1, label='Edges')

for idx, row in grid.iterrows():
    if row.geometry is not None and not row.geometry.is_empty:
        x, y = row.geometry.centroid.coords[0]
        ax.text(x, y, str(row.name), fontsize=7, color="black",
                ha="center", va="center")
        
plt.title("Sum of Sum_volume per grid cell")
plt.show()

# %%
# 1. Define the time window (first week of April 2025)
start = pd.Timestamp("2025-04-01")
end   = pd.Timestamp("2025-04-07 23:59:59")

# 2. Filter the data for that week
week_data = joined_eval[(joined_eval["End_Time"] >= start) & (joined_eval["End_Time"] <= end)]

# 3. Pick 8 random Grid_IDs from those available in that week
random_ids = [44,52,53,54,55]#np.random.choice(week_data["Grid_ID"].unique(), size=8, replace=False)

# 4. Filter again for just those IDs
subset = week_data[week_data["Grid_ID"].isin(random_ids)]

# 5. Plot
plt.figure(figsize=(12, 8))
for gid in random_ids:
    temp = subset[subset["Grid_ID"] == gid]
    plt.plot(temp["End_Time"], temp["Sum_Volume"], label=f"Grid {gid}")

plt.xlabel("End Time")
plt.ylabel("Sum Volume")
plt.title("Random 8 Grid_IDs – First Week of April 2025")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
bins = [0, 7, 10, 16, 20, 24]  # hours
labels = ["00-07", "07-10", "10-16", "16-20", "20-24"]

# extract hour of day
joined_eval["hour"] = joined_eval["End_Time"].dt.hour

# assign each row into a time bin
joined_eval["time_bin"] = pd.cut(joined_eval["hour"], bins=bins, labels=labels, right=False)

# also extract just the date (for grouping day by day)
joined_eval["date"] = joined_eval["End_Time"].dt.date

# now group by Grid_ID, date, and time_bin
grouped = (
    joined_eval
    .groupby(["Grid_ID", "date", "time_bin"])["Sum_Volume"]
    .sum()
    .reset_index()
)

grouped.head()
# Out:
# C:\Users\user1\AppData\Local\Temp\ipykernel_7944\1597695665.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby(["Grid_ID", "date", "time_bin"])["Sum_Volume"]
#    Grid_ID        date time_bin  Sum_Volume
# 0      3.0  2025-03-01    00-07        2877
# 1      3.0  2025-03-01    07-10        3029
# 2      3.0  2025-03-01    10-16       20766
# 3      3.0  2025-03-01    16-20       12818
# 4      3.0  2025-03-01    20-24        7405

# %%
grouped = pd.merge(grouped, grid, left_on="Grid_ID", right_index=True, how="left")
grouped.drop(columns=["Sum_volume"], inplace=True)
grouped.head()
# Out:
#    Grid_ID        date time_bin  Sum_Volume  \
# 0      3.0  2025-03-01    00-07        2877
# 1      3.0  2025-03-01    07-10        3029
# 2      3.0  2025-03-01    10-16       20766
# 3      3.0  2025-03-01    16-20       12818
# 4      3.0  2025-03-01    20-24        7405
#
#                                             geometry
# 0  POLYGON ((-6.36199 53.33426, -6.36199 53.34507...
# 1  POLYGON ((-6.36199 53.33426, -6.36199 53.34507...
# 2  POLYGON ((-6.36199 53.33426, -6.36199 53.34507...
# 3  POLYGON ((-6.36199 53.33426, -6.36199 53.34507...
# 4  POLYGON ((-6.36199 53.33426, -6.36199 53.34507...

# %%
# import matplotlib.pyplot as plt
# import numpy as np
# import geopandas as gpd

# # make sure grouped is a GeoDataFrame
# grouped_gdf = gpd.GeoDataFrame(grouped, geometry="geometry")

# # 1. pick a random day
# random_day = np.random.choice(grouped_gdf["date"].unique())
# day_data = grouped_gdf[grouped_gdf["date"] == random_day]

# # 2. get the time bins for that day
# time_bins = sorted(day_data["time_bin"].unique())

# # 3. loop over each time bin and plot separately
# for tb in time_bins:
#     subset = day_data[day_data["time_bin"] == tb]

#     fig, ax = plt.subplots(figsize=(8, 8))
    
#     # plot choropleth
#     subset.plot(
#         column="Sum_Volume",
#         cmap="OrRd",
#         legend=True,
#         ax=ax,
#         edgecolor="black"
#     )
    
#     # overlay geo_edges
#     geo_edges.plot(ax=ax, color="blue", linewidth=1, label="Edges")
    
#     ax.set_title(f"Choropleth for {random_day} – {tb}")
#     ax.axis("off")
#     plt.show()

# %%
geo_edges["start_point"] = geo_edges.geometry.apply(lambda x: Point(x.coords[0]))
geo_edges["end_point"]   = geo_edges.geometry.apply(lambda x: Point(x.coords[-1]))

# 2. Make GeoDataFrames for start and end points
start_gdf = gpd.GeoDataFrame(geo_edges[["start_point"]], geometry="start_point", crs=geo_edges.crs)
end_gdf   = gpd.GeoDataFrame(geo_edges[["end_point"]], geometry="end_point", crs=geo_edges.crs)

# 3. Spatial join each point set with the grid polygons
start_joined = gpd.sjoin(start_gdf, grid, how="left", predicate="within")
end_joined   = gpd.sjoin(end_gdf, grid, how="left", predicate="within")

# 4. Add Grid_IDs back to geo_edges
geo_edges["start_grid"] = start_joined["Grid_ID"].values
geo_edges["end_grid"]   = end_joined["Grid_ID"].values

geo_edges.head()
# Out:
#         u           v  key                                              osmid  \
# 0  389279  1396858852    0  [1288830596, 292236197, 1179644327, 1179644328...
# 1  389281    26165090    0                                           14039949
# 2  389281   135109542    0                                          532427444
# 3  389281  2384200130    0                                          532427444
# 4  389292  3594514232    0                               [506780985, 3789703]
#
#         highway lanes      maxspeed             name  oneway   ref  ...  \
# 0     secondary     2  ['30', '50']       Essex Quay    True  R148  ...
# 1  unclassified   NaN            30      York Street    True   NaN  ...
# 2     secondary     3            30   Aungier Street   False  R114  ...
# 3     secondary     3            30   Aungier Street   False  R114  ...
# 4     secondary     4            50  Beresford Place    True  R105  ...
#
#   access  tunnel bridge width junction est_width                start_point  \
# 0    NaN     NaN    NaN   NaN      NaN       NaN  POINT (-6.26763 53.34534)
# 1    NaN     NaN    NaN   NaN      NaN       NaN  POINT (-6.26586 53.33959)
# 2    NaN     NaN    NaN   NaN      NaN       NaN  POINT (-6.26586 53.33959)
# 3    NaN     NaN    NaN   NaN      NaN       NaN  POINT (-6.26586 53.33959)
# 4    NaN     NaN    NaN   NaN      NaN       NaN  POINT (-6.25494 53.34828)
#
#                    end_point  start_grid end_grid
# 0  POINT (-6.26999 53.34513)        44.0     44.0
# 1  POINT (-6.26433 53.33926)        43.0     53.0
# 2  POINT (-6.26566 53.34048)        43.0     43.0
# 3  POINT (-6.26611 53.33854)        43.0     43.0
# 4  POINT (-6.25495 53.34866)        54.0     54.0
#
# [5 rows x 23 columns]

# %%
joined.head()
# Out:
#              End_Time  Site  Detector  Sum_Volume                   geometry  \
# 0 2025-03-13 01:00:00    58         6           0  POINT (-6.26523 53.35605)
# 1 2025-03-13 01:00:00    58         7           5  POINT (-6.26523 53.35605)
# 2 2025-03-13 01:00:00    58         8           0  POINT (-6.26523 53.35605)
# 3 2025-03-13 01:00:00    58         9           0  POINT (-6.26523 53.35605)
# 4 2025-03-13 01:00:00    58        10           0  POINT (-6.26523 53.35605)
#
#    Grid_ID
# 0     45.0
# 1     45.0
# 2     45.0
# 3     45.0
# 4     45.0

# %%
geo_nodes = gpd.sjoin(
    geo_nodes, grid, how="left", predicate="within"
)
geo_nodes.head()
# Out:
#     osmid          y         x  street_count            highway  ref junction  \
# 0  385708  53.388802 -6.353715             3                NaN  NaN      NaN
# 1  385713  53.385852 -6.374721             4    traffic_signals  NaN      NaN
# 2  385738  53.389050 -6.375863             3                NaN  NaN      NaN
# 3  385745  53.394989 -6.375190             3    traffic_signals  NaN      NaN
# 4  385746  53.389695 -6.377564             3  motorway_junction    2      NaN
#
#   railway                   geometry  Grid_ID  Sum_volume
# 0     NaN   POINT (-6.35371 53.3888)     18.0         0.0
# 1     NaN  POINT (-6.37472 53.38585)      7.0  10664564.0
# 2     NaN  POINT (-6.37586 53.38905)      8.0         0.0
# 3     NaN  POINT (-6.37519 53.39499)      8.0         0.0
# 4     NaN  POINT (-6.37756 53.38969)      8.0         0.0

# %%
joined_count = joined.groupby("Grid_ID")["Site"].nunique()
joined_count.loc[[52,53,54,55,44,43,64,63]]
# Out:
# Grid_ID
# 52.0    24
# 53.0    41
# 54.0    51
# 55.0    21
# 44.0    35
# 43.0    24
# 64.0    19
# 63.0    11
# Name: Site, dtype: int64

# %%
# 1. get all sites in Grid_ID 53 (keep duplicates)
sites53 = joined[joined["Grid_ID"] == 53]
uniques = sites53.drop_duplicates(subset=["Site"])

# 2. select edges connected to Grid_ID 53
edges53 = geo_edges[(geo_edges["start_grid"] == 53) | (geo_edges["end_grid"] == 53)]
nodes53 = geo_nodes[geo_nodes["Grid_ID"] == 53]

# 3. get the polygon of Grid_ID 53
grid53 = grid.loc[[53]]

# 4. plot
fig, ax = plt.subplots(figsize=(8, 8))

# plot grid polygon
grid53.plot(ax=ax, facecolor="none", edgecolor="black", linewidth=2, label="Grid 53")

# plot roads
edges53.plot(ax=ax, color="blue", linewidth=1, label="Edges touching 53")
#nodes53.plot(ax=ax, facecolor="none", edgecolor="black", linewidth=2, label="Grid 53")

# plot all site points (with duplicates)
uniques.plot(ax=ax, color="red", markersize=30, alpha=0.7, label="Sites in 53")

for idx, row in uniques.iterrows():
    if row.geometry is not None and not row.geometry.is_empty:
        x, y = row.geometry.x, row.geometry.y
        ax.text(x, y, str(row["Site"]),
                fontsize=6, color="black",
                ha="left", va="bottom")

ax.set_title("All Sites in Grid 53 and Connected Roads")
ax.legend()
plt.show()
# Out:
# C:\Users\user1\AppData\Local\Temp\ipykernel_7944\113782601.py:33: UserWarning: Legend does not support handles for PatchCollection instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   ax.legend()

# %%
sites53.head()
# Out:
#                 End_Time  Site  Detector  Sum_Volume  \
# 1879 2025-03-13 01:00:00     7         1          83
# 1880 2025-03-13 01:00:00     7         2           7
# 1881 2025-03-13 01:00:00     7         3          34
# 1882 2025-03-13 01:00:00     7         4          29
# 1883 2025-03-13 01:00:00     7         5          14
#
#                        geometry  Grid_ID
# 1879  POINT (-6.24912 53.33682)     53.0
# 1880  POINT (-6.24912 53.33682)     53.0
# 1881  POINT (-6.24912 53.33682)     53.0
# 1882  POINT (-6.24912 53.33682)     53.0
# 1883  POINT (-6.24912 53.33682)     53.0

# %%
# 1. get all sites in Grid_ID 53 (keep duplicates)
selected = sites53[sites53["Site"].isin([352, 328, 920, 919])]
selected.head()
# Out:
#                 End_Time  Site  Detector  Sum_Volume  \
# 8029 2025-03-11 07:00:00   919         1         127
# 8030 2025-03-11 07:00:00   919         2           6
# 8031 2025-03-11 07:00:00   919         3           4
# 8032 2025-03-11 07:00:00   919         4           6
# 8033 2025-03-11 07:00:00   919         5           6
#
#                        geometry  Grid_ID
# 8029  POINT (-6.25824 53.34123)     53.0
# 8030  POINT (-6.25824 53.34123)     53.0
# 8031  POINT (-6.25824 53.34123)     53.0
# 8032  POINT (-6.25824 53.34123)     53.0
# 8033  POINT (-6.25824 53.34123)     53.0

# %%
geo_sites_grid = gpd.sjoin(
    geo_sites, grid, how="left", predicate="within"
)
geo_sites_grid[geo_sites_grid["Grid_ID"] == 53].head()
# Out:
#      SiteID        Site_Description_Cap      Site_Description_Lower Region  \
# 6       7.0  BAGGOT ST @ FITZWILLIAM ST  baggot st @ fitzwilliam st  SCITY
# 37     39.0       CLARE ST @ MERRION SQ       clare st @ merrion sq  CCITY
# 47     49.0        DAME ST @ GEORGES ST        dame st @ georges st  CCITY
# 70     75.0       FENIAN ST @ HOLLES ST       fenian st @ holles st  CCITY
# 105   115.0    MERRION ROW @ MERRION ST    merrion row @ merrion st  CCITY
#
#            Lat      Long                   geometry  Grid_ID  Sum_volume
# 6    53.336815 -6.249116  POINT (-6.24912 53.33682)     53.0  24839211.0
# 37   53.341155 -6.250742  POINT (-6.25074 53.34116)     53.0  24839211.0
# 47   53.344169 -6.264473  POINT (-6.26447 53.34417)     53.0  24839211.0
# 70   53.341085 -6.245314  POINT (-6.24531 53.34108)     53.0  24839211.0
# 105  53.338255 -6.253528  POINT (-6.25353 53.33826)     53.0  24839211.0

# %%
sel_detectors = selected.groupby("Site")["Detector"].nunique()
site352=selected[selected["Site"] == 352]
site352_grouped=site352.groupby("Detector")["Sum_Volume"].sum().reset_index().sort_values("Sum_Volume", ascending=False)
site352_time= site352.groupby("End_Time")
site352_grouped.head()
# Out:
#     Detector  Sum_Volume
# 2          2      164997
# 3          3       93697
# 20        20       29759
# 12        12        8796
# 7          7        8590

# %%
# take top 4 detectors for each End_Time
top_detectors = (
    site352.groupby("End_Time", group_keys=False)
    .apply(lambda g: g.nlargest(4, "Sum_Volume"))
)

# rank within each End_Time
top_detectors["rank"] = (
    top_detectors.groupby("End_Time").cumcount() + 1
)

# pivot wider: one row per End_Time, columns for top 4 detectors and volumes
result = top_detectors.pivot_table(
    index="End_Time",
    columns="rank",
    values=["Detector", "Sum_Volume"],
    aggfunc="first"
)

# flatten MultiIndex column names
result.columns = [f"{col}_{rank}" for col, rank in result.columns]
result = result.reset_index()

result.head()
# Out:
# C:\Users\user1\AppData\Local\Temp\ipykernel_7944\3494269279.py:4: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: g.nlargest(4, "Sum_Volume"))
#              End_Time  Detector_1  Detector_2  Detector_3  Detector_4  \
# 0 2025-03-01 00:00:00           2           3          20           6
# 1 2025-03-01 01:00:00          20           4           6           7
# 2 2025-03-01 02:00:00          20           0           1           2
# 3 2025-03-01 03:00:00          20           0           1           2
# 4 2025-03-01 04:00:00           0           1           2           3
#
#    Sum_Volume_1  Sum_Volume_2  Sum_Volume_3  Sum_Volume_4
# 0           209           103            29             6
# 1            20             3             3             3
# 2             1             0             0             0
# 3             1             0             0             0
# 4             0             0             0             0

# %%
result=result.sort_values("Sum_Volume_1", ascending=False)
result
# Out:
#                End_Time  Detector_1  Detector_2  Detector_3  Detector_4  \
# 273 2025-03-12 09:00:00           2           3           7           6
# 490 2025-04-07 09:00:00           2           3           7          12
# 105 2025-03-05 09:00:00           2           3           7           6
# 514 2025-04-08 09:00:00           2           3           7           6
# 683 2025-04-15 10:00:00           2           3          11           7
# ..                  ...         ...         ...         ...         ...
# 28  2025-03-02 04:00:00           0           1           2           3
# 818 2025-04-21 01:00:00           0           1           2           3
# 796 2025-04-20 03:00:00           0           1           2           3
# 603 2025-04-12 02:00:00           0           1           2           3
# 605 2025-04-12 04:00:00           0           1           2           3
#
#      Sum_Volume_1  Sum_Volume_2  Sum_Volume_3  Sum_Volume_4
# 273           398           127            24            20
# 490           363           146            26            23
# 105           361           151            21            19
# 514           359           159            23            21
# 683           358           127            19            18
# ..            ...           ...           ...           ...
# 28              0             0             0             0
# 818             0             0             0             0
# 796             0             0             0             0
# 603             0             0             0             0
# 605             0             0             0             0
#
# [1057 rows x 9 columns]

# %%
site920=selected[selected["Site"] == 920]
site920_grouped=site920.groupby("Detector")["Sum_Volume"].sum().reset_index().sort_values("Sum_Volume", ascending=False)
site920_time= site920.groupby("End_Time")
site328=selected[selected["Site"] == 328]
site328_grouped=site328.groupby("Detector")["Sum_Volume"].sum().reset_index().sort_values("Sum_Volume", ascending=False)
site328_time= site328.groupby("End_Time")

# %%
site328_grouped.head()
site352_grouped.head()
site920_grouped.head()
# Out:
#     Detector  Sum_Volume
# 0          1       89661
# 1          2       72221
# 5          6        7909
# 9         10        7901
# 10        11        7863

# %%
joined_eval["Vol_diff"] = joined_eval["Sum_Volume"].diff().fillna(0)
joined_eval.head()
# Out:
#    Grid_ID            End_Time  Sum_Volume  hour time_bin        date  \
# 0      3.0 2025-03-01 00:00:00         897     0    00-07  2025-03-01
# 1      3.0 2025-03-01 01:00:00         551     1    00-07  2025-03-01
# 2      3.0 2025-03-01 02:00:00         492     2    00-07  2025-03-01
# 3      3.0 2025-03-01 03:00:00         272     3    00-07  2025-03-01
# 4      3.0 2025-03-01 04:00:00         247     4    00-07  2025-03-01
#
#    Vol_diff
# 0       0.0
# 1    -346.0
# 2     -59.0
# 3    -220.0
# 4     -25.0

# %%
start = pd.Timestamp("2025-04-02")
end   = pd.Timestamp("2025-04-03 23:59:59")

# 2. Filter the data for that week
week_data = joined_eval[(joined_eval["End_Time"] >= start) & (joined_eval["End_Time"] <= end)]

# 3. Pick 8 random Grid_IDs from those available in that week
random_ids =  [54,44,64,55,53]  #np.random.choice(week_data["Grid_ID"].unique(), size=5, replace=False)

# 4. Filter again for just those IDs
subset = week_data[week_data["Grid_ID"].isin(random_ids)]

# 5. Plot
plt.figure(figsize=(12, 8))
for gid in random_ids:
    temp = subset[subset["Grid_ID"] == gid]
    plt.plot(temp["End_Time"], temp["Vol_diff"], label=f"Grid {gid}")

plt.xlabel("End Time")
plt.ylabel("Volume Difference")
plt.title("Random 8 Grid_IDs – First Week of April 2025")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
agg = (
    joined.groupby(["Grid_ID", "hour", "Site", "Detector"])["Sum_Volume"]
    .sum()
    .reset_index()
)

agg["Site_Detector"] = agg["Site"].astype(str) + "_" + agg["Detector"].astype(str)

# 2. For each (Grid_ID, hour), take top 10 detectors
top10 = (
    agg.groupby(["Grid_ID", "hour"], group_keys=False)
    .apply(lambda g: g.nlargest(10, "Sum_Volume"))
)

# 3. Rank them within each group
top10["rank"] = top10.groupby(["Grid_ID", "hour"]).cumcount() + 1

wide = top10.pivot_table(
    index=["Grid_ID", "hour"],
    columns="rank",
    values=["Site_Detector", "Sum_Volume"],
    aggfunc="first"
)

# flatten column names
wide.columns = [f"{col}_{rank}" for col, rank in wide.columns]
wide = wide.reset_index()

wide.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[72], line 2
#       1 agg = (
# ----> 2     joined.groupby(["Grid_ID", "hour", "Site", "Detector"])["Sum_Volume"]
#       3     .sum()
#       4     .reset_index()
#       5 )
#       7 agg["Site_Detector"] = agg["Site"].astype(str) + "_" + agg["Detector"].astype(str)
#       9 # 2. For each (Grid_ID, hour), take top 10 detectors
#
# File c:\Users\user1\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:9190, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9187 if level is None and by is None:
#    9188     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9190 return DataFrameGroupBy(
#    9191     obj=self,
#    9192     keys=by,
#    9193     axis=axis,
#    9194     level=level,
#    9195     as_index=as_index,
#    9196     sort=sort,
#    9197     group_keys=group_keys,
#    9198     observed=observed,
#    9199     dropna=dropna,
#    9200 )
#
# File c:\Users\user1\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\groupby.py:1330, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327 self.dropna = dropna
#    1329 if grouper is None:
# -> 1330     grouper, exclusions, obj = get_grouper(
#    1331         obj,
#    1332         keys,
#    1333         axis=axis,
#    1334         level=level,
#    1335         sort=sort,
#    1336         observed=False if observed is lib.no_default else observed,
#    1337         dropna=self.dropna,
#    1338     )
#    1340 if observed is lib.no_default:
#    1341     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File c:\Users\user1\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'hour'

# %%
# 1. pick the most influential detector per Grid_ID/hour
best_detectors = (
    agg.loc[agg.groupby(["Grid_ID", "hour"])["Sum_Volume"].idxmax()]
    .reset_index(drop=True)
)

# 2. sample 5 random Grid_IDs
sample_ids =      np.random.choice(best_detectors["Grid_ID"].unique(), 5, replace=False)

# 3. filter data
subset = best_detectors[best_detectors["Grid_ID"].isin(sample_ids)]

# 4. plot
fig, axes = plt.subplots(5, 1, figsize=(10, 15), sharex=True)

for ax, gid in zip(axes, sample_ids):
    temp = subset[subset["Grid_ID"] == gid]
    ax.plot(temp["hour"], temp["Detector"], marker="o")
    ax.set_title(f"Most Influential Detector per Hour – Grid {gid}")
    ax.set_ylabel("Detector ID")
    ax.set_xticks(range(0, 24, 2))  # ticks every 2 hours

plt.xlabel("Hour of Day")
plt.tight_layout()
plt.show()

# %%
# 1. aggregate by Grid_ID, hour, Site, Detector
agg = (
    joined.groupby(["Grid_ID", joined["End_Time"].dt.hour, "Site", "Detector"])["Sum_Volume"]
    .sum()
    .reset_index()
    .rename(columns={"End_Time": "hour"})
)

# 2. create a label combining Site and Detector
agg["Site_Detector"] = agg["Site"].astype(str) + "_" + agg["Detector"].astype(str)

# 3. for each Grid_ID, hour -> take top 10 site-detectors
top10 = (
    agg.groupby(["Grid_ID", "hour"], group_keys=False)
    .apply(lambda g: g.nlargest(10, "Sum_Volume"))
    .reset_index(drop=True)
)

# 4. sample 5 random Grid_IDs
sample_ids = [51,41,31,32,22,23,26,36,37,47,57,67,77] 

# 5. plot heatmaps for each Grid_ID
for gid in sample_ids:
    temp = top10[top10["Grid_ID"] == gid]

    # pivot so rows = hour, cols = site-detector, values = Sum_Volume
    pivoted = temp.pivot(index="hour", columns="Site_Detector", values="Sum_Volume")

    plt.figure(figsize=(12, 6))
    sns.heatmap(pivoted, cmap="OrRd", annot=False, cbar=True)

    plt.title(f"Grid {gid} – Top 10 Site-Detectors by Hour")
    plt.ylabel("Hour of Day")
    plt.xlabel("Site-Detector")
    plt.show()
    #hiii megan
    #Hiiiii eva
    import matplotlib
    print("Matplotlib:", matplotlib.__version__)
# Out:
# C:\Users\user1\AppData\Local\Temp\ipykernel_7500\2485209627.py:15: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: g.nlargest(10, "Sum_Volume"))
# Matplotlib: 3.10.5
# Matplotlib: 3.10.5
# Matplotlib: 3.10.5
# Matplotlib: 3.10.5
# Matplotlib: 3.10.5
# Matplotlib: 3.10.5
# Matplotlib: 3.10.5
# Matplotlib: 3.10.5
# Matplotlib: 3.10.5
# Matplotlib: 3.10.5
# Matplotlib: 3.10.5
# Matplotlib: 3.10.5
# Matplotlib: 3.10.5

# %%
#Correlation between Grid_ID time series
# 1. aggregate: total Sum_Volume per Grid_ID and End_Time (hourly)
grid_series = (
    joined.groupby(["End_Time", "Grid_ID"])["Sum_Volume"]
    .sum()
    .reset_index()
)

# 2. pivot: rows = End_Time, columns = Grid_ID, values = Sum_Volume
pivoted_grids = grid_series.pivot(
    index="End_Time", columns="Grid_ID", values="Sum_Volume"
)

# 3. correlation between Grid_IDs
corr = pivoted_grids.corr(method="pearson")

# 4. plot
plt.figure(figsize=(10, 8))
sns.heatmap(corr, cmap="coolwarm", center=0, annot=False, cbar=True)
plt.title("Correlation between Grid_ID time series")
plt.show()
#.

# %%
def correlation_map(joined, grid_id, neighbors):
    # add hour column
    joined = joined.copy()
    joined["hour"] = joined["End_Time"].dt.hour

    # time series for reference grid
    base = (
        joined[joined["Grid_ID"] == grid_id]
        .groupby(["hour", "End_Time"])["Sum_Volume"].sum()
        .reset_index()
    )

    corr_matrix = pd.DataFrame(index=neighbors, columns=range(24), dtype=float)

    for neigh in neighbors:
        neigh_series = (
            joined[joined["Grid_ID"] == neigh]
            .groupby(["hour", "End_Time"])["Sum_Volume"].sum()
            .reset_index()
        )

        # merge on End_Time to align days
        merged = pd.merge(
            base, neigh_series, on=["hour", "End_Time"],
            suffixes=("_base", "_neigh")
        )

        # compute correlation per hour
        for h in range(24):
            sub = merged[merged["hour"] == h]
            if len(sub) > 1:  # need at least 2 samples
                corr_matrix.loc[neigh, h] = sub["Sum_Volume_base"].corr(sub["Sum_Volume_neigh"])

    return corr_matrix

# Example usage
neighbors_54 = [51,41,31,32,22,23,26,36,37,47,57,67,77]  # adjust to your actual neighbor IDs
corr_map = correlation_map(joined, 54, neighbors_54)

plt.figure(figsize=(12, 6))
sns.heatmap(corr_map, cmap="coolwarm", center=0, annot=False,
            xticklabels=range(24), yticklabels=neighbors_54)
plt.xlabel("Hour of Day")
plt.ylabel("Neighboring Grid_ID")
plt.title("Hourly Correlation of Grid 54 vs Neighbors")
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[42], line 3
#       1 # 1. group traffic volumes by edge (start_grid → end_grid)
#       2 edge_flows = (
# ----> 3     joined.merge(geo_edges, left_on="Grid_ID", right_on="start_grid")
#       4     .groupby(["start_grid", "end_grid"])["Sum_Volume"]
#       5     .sum()
#       6     .reset_index()
#       7 )
#       9 # 2. build weighted adjacency matrix
#      10 import networkx as nx
#
# File c:\Users\user1\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:10839, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10820 @Substitution("")
#   10821 @Appender(_merge_doc, indents=2)
#   10822 def merge(
#    (...)  10835     validate: MergeValidate | None = None,
#   10836 ) -> DataFrame:
#   10837     from pandas.core.reshape.merge import merge
# > 10839     return merge(
#   10840         self,
#   10841         right,
#   10842         how=how,
#   10843         on=on,
#   10844         left_on=left_on,
#   10845         right_on=right_on,
#   10846         left_index=left_index,
#   10847         right_index=right_index,
#   10848         sort=sort,
#   10849         suffixes=suffixes,
#   10850         copy=copy,
#   10851         indicator=indicator,
#   10852         validate=validate,
#   10853     )
#
# File c:\Users\user1\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)    182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File c:\Users\user1\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\merge.py:886, in _MergeOperation.get_result(self, copy)
#     883 if self.indicator:
#     884     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
# --> 886 join_index, left_indexer, right_indexer = self._get_join_info()
#     888 result = self._reindex_and_concat(
#     889     join_index, left_indexer, right_indexer, copy=copy
#     890 )
#     891 result = result.__finalize__(self, method=self._merge_type)
#
# File c:\Users\user1\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\merge.py:1152, in _MergeOperation._get_join_info(self)
#    1148     join_index, right_indexer, left_indexer = _left_join_on_index(
#    1149         right_ax, left_ax, self.right_join_keys, sort=self.sort
#    1150     )
#    1151 else:
# -> 1152     (left_indexer, right_indexer) = self._get_join_indexers()
#    1154     if self.right_index:
#    1155         if len(self.left) > 0:
#
# File c:\Users\user1\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\merge.py:1126, in _MergeOperation._get_join_indexers(self)
#    1124 # make mypy happy
#    1125 assert self.how != "asof"
# -> 1126 return get_join_indexers(
#    1127     self.left_join_keys, self.right_join_keys, sort=self.sort, how=self.how
#    1128 )
#
# File c:\Users\user1\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\merge.py:1760, in get_join_indexers(left_keys, right_keys, sort, how)
#    1758     _, lidx, ridx = left.join(right, how=how, return_indexers=True, sort=sort)
#    1759 else:
# -> 1760     lidx, ridx = get_join_indexers_non_unique(
#    1761         left._values, right._values, sort, how
#    1762     )
#    1764 if lidx is not None and is_range_indexer(lidx, len(left)):
#    1765     lidx = None
#
# File c:\Users\user1\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\merge.py:1800, in get_join_indexers_non_unique(left, right, sort, how)
#    1798     ridx, lidx = libjoin.left_outer_join(rkey, lkey, count, sort=sort)
#    1799 elif how == "inner":
# -> 1800     lidx, ridx = libjoin.inner_join(lkey, rkey, count, sort=sort)
#    1801 elif how == "outer":
#    1802     lidx, ridx = libjoin.full_outer_join(lkey, rkey, count)
#
# File pandas/_libs/join.pyx:48, in pandas._libs.join.inner_join()
#
# MemoryError: Unable to allocate 38.0 GiB for an array with shape (5101780101,) and data type int64

# %%
import numpy as np
import networkx as nx
from sklearn.cluster import KMeans
from numpy.linalg import eig
import matplotlib.pyplot as plt

# ---------------------------------------------------------
# 1. Aggregate total volumes per grid
# ---------------------------------------------------------
grid_volumes = (
    joined.groupby("Grid_ID")["Sum_Volume"]
    .sum()
    .reset_index()
)

# ---------------------------------------------------------
# 2. Attach volumes to edges
#    Weight of edge = average of start/end grid volumes
# ---------------------------------------------------------
edge_flows = geo_edges.copy()

edge_flows = edge_flows.merge(
    grid_volumes, left_on="start_grid", right_on="Grid_ID", how="left"
).rename(columns={"Sum_Volume": "start_volume"}).drop(columns="Grid_ID")

edge_flows = edge_flows.merge(
    grid_volumes, left_on="end_grid", right_on="Grid_ID", how="left"
).rename(columns={"Sum_Volume": "end_volume"}).drop(columns="Grid_ID")

edge_flows["weight"] = (edge_flows["start_volume"].fillna(0) +
                        edge_flows["end_volume"].fillna(0)) / 2

# ---------------------------------------------------------
# 3. Build weighted graph
# ---------------------------------------------------------
G_flow = nx.Graph()
for _, row in edge_flows.iterrows():
    G_flow.add_edge(row["start_grid"], row["end_grid"], weight=row["weight"])

nodelist = sorted(G_flow.nodes())

# ---------------------------------------------------------
# 4. Build adjacency + Laplacian
# ---------------------------------------------------------
A_flow = nx.to_numpy_array(G_flow, weight="weight", nodelist=nodelist)
degrees = A_flow.sum(axis=1)
D_flow = np.diag(degrees)
L_flow = D_flow - A_flow

# ---------------------------------------------------------
# 5. Eigen-decomposition
# ---------------------------------------------------------
eigvals, eigvecs = eig(L_flow)

# sort eigenvalues and eigenvectors
idx = eigvals.argsort()
eigvals = eigvals[idx]
eigvecs = eigvecs[:, idx]

# pick k smallest non-trivial eigenvectors
k = 3
X = np.real(eigvecs[:, 1:k+1])

# ---------------------------------------------------------
# 6. Spectral clustering (KMeans)
# ---------------------------------------------------------
clusters = KMeans(n_clusters=k, n_init=10, random_state=0).fit_predict(X)

# ---------------------------------------------------------
# 7. Attach clusters back to grid GeoDataFrame
# ---------------------------------------------------------
if grid.index.name != "Grid_ID":
    grid = grid.set_index("Grid_ID")

# select only grids present in nodelist
available_ids = [gid for gid in nodelist if gid in grid.index]
grid_clusters = grid.loc[available_ids].copy()
grid_clusters["cluster"] = clusters[:len(available_ids)]

# ---------------------------------------------------------
# 8. Plot results
# ---------------------------------------------------------
fig, ax = plt.subplots(figsize=(10, 10))
grid_clusters.plot(column="cluster", categorical=True, cmap="tab10",
                   legend=True, ax=ax, edgecolor="black")
plt.title("Spectral Clustering of Grids based on Flow")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN


# -------------------------------------------------
# 1. Build daily profiles (avg per grid per hour)
# -------------------------------------------------
# Assume joined has: Grid_ID, Hour, Sum_Volume
daily_profiles = (
    joined.groupby(["Grid_ID", "Hour"])["Sum_Volume"]
    .mean()
    .unstack(fill_value=0)  # rows = grids, cols = 0..23 hours
)

# Scale for clustering
X = StandardScaler().fit_transform(daily_profiles.values)

# -------------------------------------------------
# 2. Run DBSCAN
# -------------------------------------------------
db = DBSCAN(eps=1.5, min_samples=5).fit(X)
daily_profiles["cluster"] = db.labels_

print(daily_profiles["cluster"].value_counts())

# -------------------------------------------------
# 3. Attach back to grid GeoDataFrame
# -------------------------------------------------
grid_clusters = grid.merge(daily_profiles["cluster"], left_on="Grid_ID", right_index=True)

# Plot static clusters
fig, ax = plt.subplots(figsize=(10, 10))
grid_clusters.plot(column="cluster", categorical=True, cmap="tab10",
                   legend=True, ax=ax, edgecolor="black")
plt.title("Static Clustering of Grids (DBSCAN on Daily Traffic Profiles)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       2 from sklearn.cluster import DBSCAN
#       5 # -------------------------------------------------
#       6 # 1. Build daily profiles (avg per grid per hour)
#       7 # -------------------------------------------------
#       8 # Assume joined has: Grid_ID, Hour, Sum_Volume
#       9 daily_profiles = (
# ---> 10     joined.groupby(["Grid_ID", "Hour"])["Sum_Volume"]
#      11     .mean()
#      12     .unstack(fill_value=0)  # rows = grids, cols = 0..23 hours
#      13 )
#      15 # Scale for clustering
#      16 X = StandardScaler().fit_transform(daily_profiles.values)
#
# NameError: name 'joined' is not defined
